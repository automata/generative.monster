# %%
# !pip install tweepy

# %%
# API Key
twitter_keys = {
    "api_key": "GQRPzXBxDgHcXonlTIUT6jq5R",
    "api_key_secret": "sKuQVCr7WYa2LWNp4PtfFzKnnt9gCmrVeeqag9LZlfMTLVozlD",
    "bearer_token": "AAAAAAAAAAAAAAAAAAAAANPDZwEAAAAAczl5dpPtGYHgJj5owtaJuJ0gxkA%3D93KfMOab0r8U1ME3pWDgmUhsZJBj1wANOPXtSzp6KIHzbMmjUG",
    "access_token": "1491966389812436992-VavmXTuhQD13ktFpsv5XiJKYeoNBCC",
    "access_token_secret": "aZ8bRpC69JSZ7S8geHzwNkdexdfYW4WNePEhHy5fupMYe"
}

# %%
import tweepy

# Authenticate to Twitter
auth = tweepy.OAuthHandler(twitter_keys["api_key"], 
    twitter_keys["api_key_secret"])
auth.set_access_token(twitter_keys["access_token"], 
    twitter_keys["access_token_secret"])

api = tweepy.API(auth)

try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")
# Out:
# Authentication OK

# %%
def update_profile(description):
    api.update_profile(description=description)

# %%
dir(api)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_list_member',
#  'add_list_members',
#  'auth',
#  'available_trends',
#  'cache',
#  'cached_result',
#  'chunked_upload',
#  'chunked_upload_append',
#  'chunked_upload_finalize',
#  'chunked_upload_init',
#  'closest_trends',
#  'create_block',
#  'create_favorite',
#  'create_friendship',
#  'create_list',
#  'create_media_metadata',
#  'create_mute',
#  'create_saved_search',
#  'delete_direct_message',
#  'destroy_block',
#  'destroy_favorite',
#  'destroy_friendship',
#  'destroy_list',
#  'destroy_mute',
#  'destroy_saved_search',
#  'destroy_status',
# ...

# %%
for tweet in api.search_tweets(q="Python", lang="en", rpp=10):
    print(f"{tweet.user.name}:{tweet.text}\n---\n")
# Out:
# Unexpected parameter: rpp
# Jakashi Bot:RT @Sheraj99: Importing Data Using #Python Cheat Sheet #DataScientist #DataScience #data #MachineLearning #BigData #Analytics #AI #Tech #II…
# ---
#
# Pythonista Bot:RT @XoceQp: CoDailychalleng: RT @aarushinair_: #AppSec optimized for the needs of #developers
# 👉https://t.co/4R4AmCv9v9
# #100DaysOfCode #Wome…
# ---
#
# Xeron Bot:RT @XoceQp: CoDailychalleng: RT @aarushinair_: #AppSec optimized for the needs of #developers
# 👉https://t.co/4R4AmCv9v9
# #100DaysOfCode #Wome…
# ---
#
# Pythonista Bot:RT @JobPreference: Need a Job?
# Sign up now https://t.co/o7lVlsl75X
# FREE. NO MIDDLEMEN
# #VR #Meta #Metaverse #GameFi #NFTs #NFTGame #NFTGivea…
# ---
#
# Xeron Bot:RT @JobPreference: Need a Job?
# Sign up now https://t.co/o7lVlsl75X
# FREE. NO MIDDLEMEN
# #VR #Meta #Metaverse #GameFi #NFTs #NFTGame #NFTGivea…
# ---
#
# Pythonista Bot:RT @Spot__Onwriters: We take the burden of having to struggle with your assignments off your shoulders. DM us.
# ...

# %%
trends_result = api.get_place_trends(1)
for trend in trends_result[0]["trends"]:
    print(trend["name"])
# Out:
# Maguire
# #MCIMUN
# 開催中祝
# #ManchesterDerby
# #MUFC
# Roy Keane
# Mahrez
# Virgínia
# Tatum
# Sancho
# Man U
# Pogba
# Andreas
# #FBvsTS
# #JuveSpezia
# De Gea
# Elche
# Rashford
# Arão
# Ronaldo
# De Bruyne
# Arsenal
# Foden
# Man City
# Fenerbahçe
# McTominay
# Lindelof
# Micah Richards
# João Gomes
# Nenê
# Lingard
# Grealish
# Hernández Hernández
# Wan Bissaka
# Querétaro
# Ferran
# اليونايتد
# Rangnick
# Ter Stegen
# Telles
# David Luiz
# Ralf
# Bruno Fernandes
# Filipe Luis
# السيتي
# Thiago Fragoso
# Etihad
# Leo Matos
# Zé Ricardo
# Mesut

# %%
api.
