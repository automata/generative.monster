# %%
from dotenv import load_dotenv
load_dotenv()

from generative_monster.generator.leap import LeapGenerator
from generative_monster.utils.image import open_image, resize_image, plot_image

# %%
gen = LeapGenerator()

# %%
image_path = gen.generate("a robot")

# %%
img = open_image(image_path)
plot_image(resize_image(img, 2))
