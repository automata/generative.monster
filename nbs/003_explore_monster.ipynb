# %%
from generative_monster.core import Monster 
from generative_monster.utils.image import open_image, plot_image

# %%
# Standard creation
m = Monster()
img_path = m.create(publish=True)
# Out:
# -- Memory and inspiration
# Generated description: "Fragile Beauty" - A delicate balance of life and death.
# --- Style
# Selected style: wes_anderson
# --- Prompt creation
# Final prompt: "Fragile Beauty" - A delicate balance of life and death. , in the style of Wes Anderson, hyper realistic, symmetry, 16k
# -- Image generation
# Selected generator: leap
# Still processing...
# Still processing...
# Still processing...
# Still processing...
# Still processing...
# Still processing...
# Still processing...
# Generated image: /tmp/generated_07fe97bf825d47a0911310290e5939b8.jpg
# -- Validating image
# Valid image...
# -- Scaling image up
# Scaled image by x2
# -- Communication
# Tweet: Response(data={'edit_history_tweet_ids': ['1669751814172946432'], 'id': '1669751814172946432', 'text': 'https://t.co/z3NPh7eaKy'}, includes={}, errors=[], meta={})

# %%
plot_image(open_image(img_path))

# %%
# Straight
m = Monster()
img_path = m.create_from_prompt("a robot", "wes_anderson", "leap")
# Out:
# 	Prompt: a robot, in the style of Wes Anderson, hyper realistic, symmetry, 16k
# Still processing...
# Still processing...
# Still processing...
# Still processing...
# 	Image: /tmp/generated_38bfffc1e1d14c69ade8d21b8fe00ba6.jpg

# %%
plot_image(open_image(img_path))
